# %% [markdown]
# # 7장 데이터 정제 및 준비 실습해보기

# %%
import pandas as pd
import numpy as np
float_data = pd.Series([1.2, -3.5, np.nan, 0])
float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
float_data.isna() # 결측치를 자료형에 상관 없이 처리할 수 있도록 추상화 해둠
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# ## 기본적인 input 함수 사용법
# 알고리즘 문제 풀때는 sys라이브러리로 빠르게 처리하는 방법 있는데 사실 데이터 분석 하면서 입력 받을일은 없어서 그냥 넘기셈

# %%
a =input("입력:")
print(a)
# Out:
# ㄴㅁㅇ

# %%
str1 = '123'
str1 = int(str1)
print(str1 + 1)
# Out:
# 124

# %%
print("2025", "02", "23", sep = "-")
print("zz", end = 'zz')
# Out:
# 2025-02-23
# zzzz

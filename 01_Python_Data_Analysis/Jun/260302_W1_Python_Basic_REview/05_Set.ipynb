# %% [markdown]
# ## 5. Set

# %% [markdown]
# ### 5.1. 기초

# %%
eg = set([1, 2, 2, 3])
print(f"set 자료형은 중복된 값을 허용하지 않는다.\n{eg}")
s1 = set([1, 2, 3])
s2 = set([3, 4, 5])
# Out:
# set 자료형은 중복된 값을 허용하지 않는다.
# {1, 2, 3}
